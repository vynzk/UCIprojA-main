# %% [markdown]
# # Proyecto taller de ciencias de datos: Reducción de las falsas alarmas de arritmia en la UCI.
# *Valentina Yañez*
#
# Este proyecto tiene como objetivo el desarrollar un algoritmo para reducir la incidencia de falsas alarmas al momento de detectar arritmias potencialmente mortales en la Unidad de Cuidados Intensivos (UCI).
#
# ## 1. Objetivo del proyecto
#
# - **Reducción de Alarmas Falsas**: El objetivo principal es desarrollar algoritmos que reduzcan la cantidad de alarmas falsas en la UCI, enfocándose en arritmias que amenazan la vida como asistolia, bradicardia extrema, taquicardia extrema, taquicardia ventricular y fibrilación ventricular. Se pueden usar hasta 30 segundos de datos después de la alarma.
# - **Evaluación y Puntuación**: Las entradas se deben evaluar y puntuar automáticamente en un entorno de prueba. Se deben maximizar los verdaderos positivos y negativos, minimizando los falsos positivos y negativos. [3]
#
# ## 2. Contexto
#
# Las falsas alarmas en la UCI pueden provocar una interrupción de la atención, afectando tanto al paciente como al personal clínico a través de perturbaciones acústicas, desensibilización a las advertencias y ralentización de los tiempos de respuesta, lo que lleva a una disminución de la calidad de la atención. [3]
#
# Se utilizan datos de 1250 alarmas de arritmia en señales de unidades de monitorización de cuidados intensivos disparadas en base a diversos canales para monitoreo de ondas pulsátiles, como derivaciones ECG, presión arterial y fotoplestimografía [3]. Sin embargo, Los datos de alarmas se reparten en sólo 750 casos únicos.
# Fueron recopilados de cuatro hospitales en EE.UU. y Europa con tres fabricantes principales.
#
# Los datos fueron recopilados de cuatro hospitales en EE.UU. y Europa con tres fabricantes principales [3] y se encuentran en formato '.hea' y '.mat' (Matlab).
#
# Cada uno de los 750 registros contiene almenos una derivacion de ECG y una o más formas de onda pulsátiles (fotopletismograma y presión arterial) y han sido muestreados a 250 Hz. Los registros incluyen artefactos de marcapasos y otros ruidos. [3]
#
# ![image-2.png](attachment:image-2.png)
#
# *Imagen representativa de los datos a evaluar*
#
# #### 2.1 Definiciones importantes
#
# **QRS**
#
# El complejo QRS es una parte fundamental del electrocardiograma (ECG) que representa la despolarización de los ventrículos del corazón.
#
# - **Despolarización Ventricular**: El complejo QRS muestra la actividad eléctrica que ocurre cuando los ventrículos del corazón se despolarizan, lo que lleva a su contracción.
# - **Componentes**:
#     - **Onda Q**: La primera onda negativa del complejo.
#     - **Onda R**: La primera onda positiva.
#     - **Onda S**: La onda negativa que sigue a la onda R.
#
# ![image.png](attachment:image.png)
#
# [4][5]
#
# **Ondas pulsátiles**
#
# son variaciones periódicas en la presión de los vasos sanguíneos, causadas por el bombeo del corazón. Estas ondas se pueden medir a través de diferentes métodos, como la **fotopletismografía (PPG)** o la **presión arterial**.
#
# #### 2.2 Tabla tipos de canales de onda pulsátil presentes en los datos
#
# | **Señal** | **Descripción** |
# |-----------|------------------|
# | **ABP (Arterial Blood Pressure)** | Mide la presión arterial en tiempo real, fundamental para el monitoreo cardiovascular. |
# | **PLETH (Plethysmogram)** | Representa la variación del volumen sanguíneo en un lecho vascular, útil para evaluar la perfusión y la saturación de oxígeno. |
# | **MCL (Modified Chest Lead)** | Derivación ECG que proporciona una visualización clara del ritmo cardíaco y ayuda en la detección de arritmias. |
# | **II (Lead II)** | Una derivación estándar que mide la actividad eléctrica del corazón desde el brazo derecho a la pierna izquierda. |
# | **V (Precordial Lead)** | Derivaciones colocadas en el tórax para obtener información detallada sobre la actividad eléctrica del corazón. |
# | **aVR, aVL, aVF** | Derivaciones unipolares que ofrecen información sobre el eje eléctrico del corazón y son útiles en la evaluación de isquemia. |
# | **RESP (Respiratory Rate)** | Mide la frecuencia respiratoria del paciente, crucial para evaluar su estado respiratorio. |
#
# [1][5]
#
# #### 2.3 Tipos de arritmia consideradas
#
# El problema solo se enfoca en algunas arritmias potencialmente mortales, a saber: asistolia, bradicardia extrema, taquicardia extrema, taquicardia ventricular y aleteo/fibrilación ventricular.
#
# | Asistolia | Sin QRS durante al menos 4 segundos |
# | --- | --- |
# | Bradicardia extrema | Frecuencia cardíaca inferior a 60 lpm durante 5 latidos consecutivos |
# | Taquicardia extrema | Frecuencia cardíaca superior a 140 lpm durante 17 latidos consecutivos |
# | Taquicardia ventricular | 5 o más latidos ventriculares con frecuencia cardíaca superior a 100 lpm |
# | Aleteo ventricular/Fibrilación | Fibrilatoria, aleteo o forma de onda oscilatoria durante al menos 4 segundos |
#
# [2]
#
# # 3. Plan de desarrollo del proyecto
#
# 3.1. **Preparación del Entorno**
#
#     - Instalar en Python las bibliotecas necesarias: `numpy`, `pandas`, `scipy`, `matplotlib`, `wfdb`.
#     - Descarga los datos de entrenamiento y prueba desde el sitio de PhysioNet.
# 3.2. **Exploración y Preprocesamiento de Datos**
#
#     - Cargar los datos utilizando la biblioteca `wfdb`.
#     - Realizar un análisis exploratorio de los datos para entender su estructura y contenido.
#     - Aplicar filtros y técnicas de limpieza para eliminar el ruido y las señales no deseadas. (encoders)
# 3.3. **Desarrollo del Algoritmo**
#
#     - Implementar un algoritmo utilizando técnicas de aprendizaje automático, como Random Forest o SVM.
#     - Evalúar el rendimiento del algoritmo en el conjunto de datos de entrenamiento.
# 3.4. **Validación y Optimización**
#
#     - Dividir los datos de entrenamiento en subconjuntos de validación cruzada.
#     - Ajustar los hiper parámetros del modelo para mejorar su precisión y reducir los falsos positivos.
#     - Implementar técnicas de validación cruzada para asegurar la robustez del modelo.
# 3.5. **Pruebas**
#
#     - Probar el algoritmo en el conjunto de datos de prueba.
#
# Cabe destacar que el plan de desarrollo corresponderá a un sólo tipo de anomalía (Bradicardia extrema), debido a que por falta de conocimiento previo se invirtió demasiado tiempo en investigación, ensayos de prueba y errores constantes, lo que dificultó el desarrollo completo del reto lamentablemente.

# %% [markdown]
# # 3.1 Preparación del entorno

# %%
# Instalar bibliotecas necesarias
import wfdb
import scipy.io as sio
import matplotlib.pyplot as plt
import numpy as np
from scipy.io import loadmat
import os
import pandas as pd
from scipy.signal import butter, filtfilt
from biosppy.signals import ecg
from biosppy.signals import ppg
from biosppy.plotting import plot_ecg
from biosppy.plotting import plot_ppg

from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import classification_report
from sklearn.ensemble import RandomForestClassifier

# %%
#Función para limpiar carpetas
def limpiar_carpeta(carpeta):
    for file in os.listdir(carpeta):
        os.remove(carpeta+'/'+file)

limpiar_carpeta('data/cleaned')

# %%
# Funciones de obtención de datos

def get_name_files(path,type):
    files = []
    for file in os.listdir(path):
        if file.endswith(type):
            files.append(file[:-4])
    return files

def read_file_hea(filename, path):
    # lee archivo .hea
    record = wfdb.rdheader(path+filename)
    return record

def read_file_mat(file, path):
    # carga archivo .mat (tiene las señales)
    mat_data = loadmat(path + file +'.mat')
    signals = mat_data['val']
    return signals

def read_file_flat(file,path):
    mat_data = loadmat(path + file +'.mat')
    if 'flatareas' in mat_data:
        flatareas = mat_data['flatareas']
    else:
        flatareas = np.array([])
    return flatareas

def read_file_zigzag(file,path):
    mat_data = loadmat(path + file +'.mat')
    if 'zigzagareas' in mat_data:
        zigzagareas = mat_data['zigzagareas']
    else:
        zigzagareas = np.array([])
    return zigzagareas

# %% [markdown]
# ---

# %% [markdown]
# # 3.2 Análisis exploratorio de datos

# %%
old_path='data/training/' #ruta de los archivos preliminares
#toma los nombres de los archivos .hea
nameFiles = get_name_files(old_path,'.hea')
#revisa el primer archivo .hea
heaRecord1 = read_file_hea(nameFiles[0], old_path)
print(heaRecord1.__dict__)
# Out:
# {'record_name': 'a103l', 'n_sig': 3, 'fs': 250, 'counter_freq': None, 'base_counter': None, 'sig_len': 82500, 'base_time': None, 'base_date': None, 'comments': ['Asystole', 'False alarm'], 'sig_name': ['II', 'V', 'PLETH'], 'p_signal': None, 'd_signal': None, 'e_p_signal': None, 'e_d_signal': None, 'file_name': ['a103l.mat', 'a103l.mat', 'a103l.mat'], 'fmt': ['16', '16', '16'], 'samps_per_frame': [1, 1, 1], 'skew': [None, None, None], 'byte_offset': [24, 24, 24], 'adc_gain': [7247.0, 10520.0, 12530.0], 'baseline': [0, 0, 0], 'units': ['mV', 'mV', 'NU'], 'adc_res': [16, 16, 16], 'adc_zero': [0, 0, 0], 'init_value': [-171, 9127, 6042], 'checksum': [-27403, -301, -17391], 'block_size': [0, 0, 0]}

# %%
all_unique_sig_names = set()
for file in nameFiles:
    record = read_file_hea(file, old_path)
    all_unique_sig_names.update(record.sig_name)

print(f"Nombres de canal presentes: {all_unique_sig_names}")
print(f"Total de canales: {len(all_unique_sig_names)}")
# Out:
# Nombres de canal presentes: {'ABP', 'PLETH', 'MCL', 'II', 'V', 'aVR', 'III', 'I', 'aVF', 'aVL', 'RESP'}
# Total de canales: 11

# %%
# contar cuantos datos .mat hay en data/training
i=0
for file in os.listdir('data/training/'):
    if file.endswith('.mat'):
        i += 1
print('cantidad de datos:', i)
# Out:
# cantidad de datos: 750

# %% [markdown]
# ## 3.2.1 Funciones de visualización

# %% [markdown]
# Se desarrollaron funciones de visualización para observar las caracteristicas de los datos de manera gráfica, junto con una recopilación en '.csv' de todos los archivos '.hea' de cada archivo para observar sus características disponible aquí [ExploraciónHea](data/exploraciónHea.csv)
#
# Entre las funciones más útiles se encuentra 'graf_signals', con ella se exportó una gráfica de cada caso en formato '.jpg'. Los gráficos pueden encontrarse aquí [Gráficos de señal preliminar](data/imgs)

# %%
def grafica_ecg(record, signals, path_save,picos_r=None): #subfunción de graf_signals
  
    plt.figure(figsize=(12, 6))
    for i in range(len(record.sig_name)):
        plt.subplot(len(record.sig_name), 1, i+1)
        plt.plot(signals[i, :], label=f'Señal: {record.sig_name[i]}')
        if picos_r is not None:
            plt.plot(picos_r, signals[i, picos_r], 'ro', markersize=1)
            #Imprime los picos_r
            print(f'Picos R señal {record.sig_name[i]}: {picos_r}')

        plt.xlabel('Muestras')
        plt.ylabel(record.units[i])
        plt.legend()

    plt.suptitle(record.comments[0] + ' - ' + record.comments[1])
  
    plt.savefig(path_save + record.record_name + '.jpg')
    plt.close()

#función para graficar una cantidad de señales/casos de un directorio de archivos .mat
def graf_signals(files, path, cant, path_save):
    for fileName in files[:cant]:
        print('Graficando señales de: ', fileName)
        record = read_file_hea(fileName, 'data/training/')
        signals, flat_areas, zigzag_areas = read_file_mat(fileName, path) 
        #picos_r = sio.loadmat(path +file+'.mat')['picos_r']
        grafica_ecg(record,signals, path_save)

# Grafica todos los canales de una señal/caso con sus areas planas y zigzag
def grafica_preview(record, signals, oldSignal, path, flat_areas=[], zigzag_areas=[]):
    plt.figure(figsize=(12, 6))
    for i in range(signals.shape[0]):
        plt.subplot(signals.shape[0], 1, i + 1)
        plt.plot(signals[i, :], label=f'Señal limpia: {record.sig_name[i]}', color='blue', alpha=0.5)
        plt.plot(oldSignal[i, :], label=f'Señal original: {record.sig_name[i]}', color='red', alpha=0.3)
        # Resaltar visualmente los segmentos planos si existen

        if  flat_areas.size > 0:
            for flat in flat_areas[0,i]:
                plt.axvspan(flat[0], flat[1], color='red', alpha=0.5)

        # Resaltar visualmente los segmentos zigzag si existen
        if zigzag_areas.size > 0:
            for zigzag in zigzag_areas[0,i]:
                plt.axvspan(zigzag[0], zigzag[1], color='yellow', alpha=0.5)
        
        plt.xlabel('Muestras')
        plt.ylabel(record.units[i])
        plt.legend()

    plt.suptitle(record.comments[0] + ' - ' + record.comments[1])
    plt.show()

#Grafica sólo canales ya procesados, mostrando sus picosR en caso de ecg, picos en caso de ppg y latidos cardiacos y complejo QRS
def grafica_preview_bios(record, signal):
    try:
        ecg_type = ['I', 'II', 'III', 'V']
        pleth_type = ['PLETH']
        for i in range(len(record.sig_name)):
            channel = signal[i, :]
            if record.sig_name[i] in ecg_type:
                ecg.ecg(signal=channel, sampling_rate=250, show=True)
            elif record.sig_name[i] in pleth_type:
                ppg.ppg(signal=channel, sampling_rate=250, show=True)
    except Exception as e:
        print(f'Señal {record.record_name} no válida para esta gráfica: {e}')

# %%
# Visualizador general: Grafica toda la información útil de una señal
def visualizador_señales_en_file(nameFile_, path, old_path):
    nameFile = nameFiles.index(nameFile_) #nombre de la muestra
    record = read_file_hea(nameFiles[nameFile], old_path) #buscar . hea siempre será en old_path
    signalPreview = read_file_mat(nameFiles[nameFile], path)
    oldSignal = read_file_mat(nameFiles[nameFile], old_path)
    flat_areas = read_file_flat(nameFiles[nameFile], path)
    zigzag_areas = read_file_zigzag(nameFiles[nameFile], path)

    grafica_preview(record, signalPreview, oldSignal, path, flat_areas, zigzag_areas)
    grafica_preview_bios(record, signalPreview) #sólo para señales correctas

def visualizador_señales_limpias(record, signals):
    ecg_type = ['I', 'II', 'III', 'V']
    pleth_type = ['PLETH']
    print(record.comments[0] + ' - ' + record.comments[1])
    for i in range(len(record.sig_name)):
        print(record.sig_name[i])
        channel = signals[i, :]
        if record.sig_name[i] in ecg_type:
            a=ecg.ecg(signal=channel, sampling_rate=250, show=True)
        elif record.sig_name[i] in pleth_type:
            ppg.ppg(signal=channel, sampling_rate=250, show=True)

# %% [markdown]
# ## 3.2.2 Limpieza de los datos
#
# Gracias a las funciones de visualización se pueden observar caracteristicas importantes de la señal.
#
# En primer lugar se observó estas no tenían una longitud estándar, muchas poseían ruido y no se identificaba a simple vista el complejo QRS.
# Además muchos canales poseían líneas planas y en zigzag, lo que dificulta aún mas la detección de características.
#
# Debido a esto se determina el siguiente plan de acción:
# - Detección de lineas planas y zig_zag.
# - Desarrollo de un filtro butterworth de paso bajo, con un cutoff=1 y order=2. [2]
# - Clasificar datos válidos para entrenamiento y testing.
#
# Se detallan a continuación funciones importantes:
#
# **mark_flat_lines** : Marca líneas planas en la señal donde la diferencia entre valores consecutivos es menor que un umbral.
#
# Parameteros:
# - signal: La señal a analizar (ECG o PPG).
# - fs: Frecuencia de muestreo en Hz.
# - min_duration: Duración mínima en segundos para que se considere una línea plana.
# - flat_value: El valor que se utilizará para marcar las líneas planas en la señal.
# - threshold: Umbral de diferencia entre muestras consecutivas para considerar una línea plana.
#
# Returns:
# - marked_signal: La señal con las líneas planas marcadas.
# - flat_areas: Lista de tuplas (inicio, fin) que indican las áreas planas detectadas.
#
# **mark_zigzag_lines** :  Identifica segmentos en zigzag en una señal.
#
# Parámetros:
# - signal (numpy array): La señal a analizar.
# - fs (int): Frecuencia de muestreo en Hz. Por defecto es 250 Hz.
# - min_duration (float): Duración mínima en segundos de un zigzag. Por defecto es 0.2 segundos.
#
# Retorna:
# zigzag_areas (list): Lista de tuplas (inicio, fin) de los segmentos en zigzag.
#
# Tanto 'min_duration' como 'threshold' fueron ajustados para detectar correctamente señales sin actividad necesaria, o de nula actividad.

# %%
def mark_flat_lines(signal, fs=250, min_duration=0.3, flat_value=-9999, threshold=2):
    # Número de muestras consecutivas que definen una línea plana
    min_samples = int(min_duration * fs)

    # Diferencias absolutas entre muestras consecutivas
    diff_signal = np.abs(np.diff(signal))

    # Encuentra dónde la diferencia es menor que el umbral
    flat_segments = (diff_signal < threshold).astype(int)

    # Identifica segmentos planos continuos de al menos min_samples de duración
    flat_areas = []
    current_length = 0
    start_index = None

    for i in range(len(flat_segments)):
        if flat_segments[i] == 1:  # Si es un segmento plano
            if current_length == 0:
                start_index = i
            current_length += 1
        else:
            if current_length >= min_samples:  # Si cumple con la duración mínima
                flat_areas.append((start_index, start_index + current_length))
            current_length = 0

    # Considerar el último segmento si termina en una zona plana
    if current_length >= min_samples:
        flat_areas.append((start_index, start_index + current_length))

    # Marca los segmentos planos en la señal
    marked_signal = np.copy(signal)
    for start, end in flat_areas:
        marked_signal[start:end] = flat_value  # Marcar con un valor específico como -9999
    
    return marked_signal, flat_areas

def mark_zigzag_lines(signal, fs=250, min_duration=0.3):
    # Número de muestras consecutivas que definen un zigzag
    min_samples = int(min_duration * fs)
    
    # Calcula las diferencias entre muestras consecutivas (pendiente)
    diff_signal = np.diff(signal)
    
    # Determina si la pendiente es positiva o negativa
    sign_changes = np.sign(diff_signal)
    
    # Identifica los cambios de signo consecutivos (zigzag)
    zigzag_segments = (sign_changes[:-1] * sign_changes[1:] == -1).astype(int)

    # Identifica segmentos zigzag continuos de al menos min_samples de duración
    zigzag_areas = []
    current_length = 0
    start_index = None
    
    for i in range(len(zigzag_segments)):
        if zigzag_segments[i] == 1:  # Cambio de pendiente
            if current_length == 0:
                start_index = i
            current_length += 1
        else:
            if current_length >= min_samples:
                zigzag_areas.append((start_index, start_index + current_length + 1))
            current_length = 0

    # Último segmento
    if current_length >= min_samples:
        zigzag_areas.append((start_index, start_index + current_length + 1))
    
    return zigzag_areas

# filtro butterworth
def butter_bandpass_filter(data, cutoff=1, fs=250, order=2):
    nyquist = 0.5 * fs
    normal_cutoff = cutoff / nyquist
    b, a = butter(order, normal_cutoff, btype='low', analog=False)
    y = filtfilt(b, a, data)
    return y

# %% [markdown]
# ### 3.2.2.1 Selección de datos válidos
#
# Para la clasificación de EBC, ETC y ASY, las señales
# de ECG y PPG estaban presentes en todos los casos. [2]
#
# En el caso de VFB y VTA, debería ser limitada
# únicamente a las señales de ECG, ya que los datos de PPG eran muy
# irregulares y no ayudaban a realizar ninguna predicción razonable. [2]
#
# Con esta información, se determina que almenos un canal derivado de ECG debería tener una señal 'limpia', es decir, libre de líneas planas y zig-zag para poder extraer sus características QRS, latidos cardiacos y picos R. Con esta condición, ese caso en particular se considera válido.
#
# Con respecto a los canales 'PLETH' se determina más adelante si califican para considerar sus caracterísiticas, ya que depende del tipo de arritmia su utilización.
#
# Además de esto se crea directorio para los datos válidos ('data/cleaned')

# %%
new_path = 'data/cleaned/'

if not os.path.exists(new_path):
    os.makedirs(new_path)
    
#se separan las señales calificadas y las no calificadas
for fileName in nameFiles:
    path = old_path
    record = read_file_hea(fileName, path)
    signals = read_file_mat(fileName, path)

    # Recorta y deja sólo los últimos 10 segundos de señal
    signals = signals[:, -record.fs*20:]
    dirtySignals = signals

    # Se aplica filtro sólo a las señales ECG ('I', 'II', 'III' y 'V')
    ecg_type = ['I', 'II', 'III', 'V']
    flat_areas_all = []
    zigzag_areas_all = []

    my_ecg = []
    strike = 0

    try:
        for i in range(len(record.sig_name)):
            if record.sig_name[i] in ecg_type and record.sig_name[i] not in my_ecg:
                my_ecg.append(record.sig_name[i])
                
        for i in range(len(record.sig_name)):

            if record.sig_name[i] in ecg_type:
                
                flat_signal, flat_areas0 = mark_flat_lines(signals[i, :], fs=record.fs)
                zigzag_areas0 = mark_zigzag_lines(signals[i, :], fs=record.fs)

            if len(flat_areas0) != 0 or len(zigzag_areas0) != 0:
                strike = strike + 1

        if strike >= len(my_ecg):
            raise Exception('Señal no califica para ser del training, no contiene ecg limpias'.format(fileName))

        else:
            sio.savemat(new_path + fileName + '.mat', {
            'val': signals,
            })

            print('se guardó la señal ', fileName, ' en el directorio cleaned')

    except Exception as e:
        print(f'Señal corrupta {fileName}: {e}')
        print(f'Señal no califica para ser del training {fileName} se descarta todo su archivo')

        
        
# se elimino 'v846s' de forma manual ya que saltó el filtro de líneas planas-zigzag y posee anomalías
os.remove('data/cleaned/v846s.mat')
# Out:
# se guardó la señal  a103l  en el directorio cleaned
# se guardó la señal  a104s  en el directorio cleaned
# se guardó la señal  a105l  en el directorio cleaned
# se guardó la señal  a109l  en el directorio cleaned
# Señal corrupta a123l: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training a123l se descarta todo su archivo
# Señal corrupta a134s: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training a134s se descarta todo su archivo
# se guardó la señal  a142s  en el directorio cleaned
# se guardó la señal  a145l  en el directorio cleaned
# Señal corrupta a152s: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training a152s se descarta todo su archivo
# se guardó la señal  a161l  en el directorio cleaned
# se guardó la señal  a163l  en el directorio cleaned
# se guardó la señal  a165l  en el directorio cleaned
# se guardó la señal  a167l  en el directorio cleaned
# se guardó la señal  a170s  en el directorio cleaned
# Señal corrupta a171l: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training a171l se descarta todo su archivo
# se guardó la señal  a172s  en el directorio cleaned
# Señal corrupta a178s: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training a178s se descarta todo su archivo
# se guardó la señal  a185l  en el directorio cleaned
# se guardó la señal  a186s  en el directorio cleaned
# se guardó la señal  a203l  en el directorio cleaned
# Señal corrupta a219l: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training a219l se descarta todo su archivo
# se guardó la señal  a223l  en el directorio cleaned
# se guardó la señal  a225l  en el directorio cleaned
# se guardó la señal  a226s  en el directorio cleaned
# Señal corrupta a239l: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training a239l se descarta todo su archivo
# Señal corrupta a266s: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training a266s se descarta todo su archivo
# Señal corrupta a267l: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training a267l se descarta todo su archivo
# se guardó la señal  a272s  en el directorio cleaned
# se guardó la señal  a273l  en el directorio cleaned
# se guardó la señal  a278s  en el directorio cleaned
# Señal corrupta a279l: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training a279l se descarta todo su archivo
# Señal corrupta a287l: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training a287l se descarta todo su archivo
# Señal corrupta a288s: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training a288s se descarta todo su archivo
# se guardó la señal  a297l  en el directorio cleaned
# se guardó la señal  a301l  en el directorio cleaned
# se guardó la señal  a302s  en el directorio cleaned
# Señal corrupta a306s: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training a306s se descarta todo su archivo
# se guardó la señal  a310s  en el directorio cleaned
# se guardó la señal  a311l  en el directorio cleaned
# se guardó la señal  a315l  en el directorio cleaned
# Señal corrupta a345l: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training a345l se descarta todo su archivo
# Señal corrupta a363l: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training a363l se descarta todo su archivo
# se guardó la señal  a372s  en el directorio cleaned
# se guardó la señal  a376s  en el directorio cleaned
# se guardó la señal  a377l  en el directorio cleaned
# se guardó la señal  a378s  en el directorio cleaned
# Señal corrupta a382s: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training a382s se descarta todo su archivo
# Señal corrupta a385l: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training a385l se descarta todo su archivo
# Señal corrupta a386s: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training a386s se descarta todo su archivo
# Señal corrupta a391l: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training a391l se descarta todo su archivo
# Señal corrupta a396s: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training a396s se descarta todo su archivo
# se guardó la señal  a397l  en el directorio cleaned
# se guardó la señal  a420s  en el directorio cleaned
# se guardó la señal  a422s  en el directorio cleaned
# se guardó la señal  a429l  en el directorio cleaned
# Señal corrupta a435l: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training a435l se descarta todo su archivo
# Señal corrupta a436s: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training a436s se descarta todo su archivo
# se guardó la señal  a439l  en el directorio cleaned
# se guardó la señal  a442s  en el directorio cleaned
# se guardó la señal  a443l  en el directorio cleaned
# se guardó la señal  a446s  en el directorio cleaned
# se guardó la señal  a449l  en el directorio cleaned
# se guardó la señal  a457l  en el directorio cleaned
# se guardó la señal  a461l  en el directorio cleaned
# Señal corrupta a462s: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training a462s se descarta todo su archivo
# Señal corrupta a465l: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training a465l se descarta todo su archivo
# Señal corrupta a490s: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training a490s se descarta todo su archivo
# Señal corrupta a512s: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training a512s se descarta todo su archivo
# se guardó la señal  a514s  en el directorio cleaned
# se guardó la señal  a526s  en el directorio cleaned
# se guardó la señal  a527l  en el directorio cleaned
# se guardó la señal  a539l  en el directorio cleaned
# Señal corrupta a550s: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training a550s se descarta todo su archivo
# se guardó la señal  a555l  en el directorio cleaned
# se guardó la señal  a556s  en el directorio cleaned
# se guardó la señal  a558s  en el directorio cleaned
# se guardó la señal  a582s  en el directorio cleaned
# se guardó la señal  a584s  en el directorio cleaned
# se guardó la señal  a591l  en el directorio cleaned
# se guardó la señal  a599l  en el directorio cleaned
# se guardó la señal  a603l  en el directorio cleaned
# Señal corrupta a604s: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training a604s se descarta todo su archivo
# se guardó la señal  a606s  en el directorio cleaned
# Señal corrupta a608s: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training a608s se descarta todo su archivo
# Señal corrupta a624s: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training a624s se descarta todo su archivo
# se guardó la señal  a631l  en el directorio cleaned
# se guardó la señal  a639l  en el directorio cleaned
# Señal corrupta a645l: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training a645l se descarta todo su archivo
# Señal corrupta a650s: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training a650s se descarta todo su archivo
# Señal corrupta a651l: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training a651l se descarta todo su archivo
# se guardó la señal  a653l  en el directorio cleaned
# Señal corrupta a654s: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training a654s se descarta todo su archivo
# se guardó la señal  a661l  en el directorio cleaned
# Señal corrupta a667l: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training a667l se descarta todo su archivo
# Señal corrupta a668s: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training a668s se descarta todo su archivo
# se guardó la señal  a670s  en el directorio cleaned
# se guardó la señal  a673l  en el directorio cleaned
# se guardó la señal  a675l  en el directorio cleaned
# se guardó la señal  a694s  en el directorio cleaned
# se guardó la señal  a699l  en el directorio cleaned
# se guardó la señal  a705l  en el directorio cleaned
# se guardó la señal  a712s  en el directorio cleaned
# se guardó la señal  a715l  en el directorio cleaned
# se guardó la señal  a723l  en el directorio cleaned
# se guardó la señal  a735l  en el directorio cleaned
# se guardó la señal  a740s  en el directorio cleaned
# se guardó la señal  a746s  en el directorio cleaned
# Señal corrupta a750s: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training a750s se descarta todo su archivo
# se guardó la señal  a754s  en el directorio cleaned
# se guardó la señal  a776s  en el directorio cleaned
# Señal corrupta a778s: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training a778s se descarta todo su archivo
# se guardó la señal  a780s  en el directorio cleaned
# se guardó la señal  a785l  en el directorio cleaned
# Señal corrupta a796s: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training a796s se descarta todo su archivo
# se guardó la señal  a798s  en el directorio cleaned
# se guardó la señal  a802s  en el directorio cleaned
# se guardó la señal  a807l  en el directorio cleaned
# se guardó la señal  a810s  en el directorio cleaned
# se guardó la señal  a819l  en el directorio cleaned
# se guardó la señal  a822s  en el directorio cleaned
# Señal corrupta a825l: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training a825l se descarta todo su archivo
# se guardó la señal  a847l  en el directorio cleaned
# se guardó la señal  b124s  en el directorio cleaned
# se guardó la señal  b125l  en el directorio cleaned
# se guardó la señal  b126s  en el directorio cleaned
# se guardó la señal  b183l  en el directorio cleaned
# se guardó la señal  b184s  en el directorio cleaned
# se guardó la señal  b187l  en el directorio cleaned
# se guardó la señal  b215l  en el directorio cleaned
# Señal corrupta b216s: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training b216s se descarta todo su archivo
# Señal corrupta b220s: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training b220s se descarta todo su archivo
# se guardó la señal  b227l  en el directorio cleaned
# se guardó la señal  b228s  en el directorio cleaned
# se guardó la señal  b229l  en el directorio cleaned
# se guardó la señal  b231l  en el directorio cleaned
# se guardó la señal  b265l  en el directorio cleaned
# se guardó la señal  b268s  en el directorio cleaned
# se guardó la señal  b269l  en el directorio cleaned
# se guardó la señal  b285l  en el directorio cleaned
# Señal corrupta b286s: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training b286s se descarta todo su archivo
# se guardó la señal  b299l  en el directorio cleaned
# Señal corrupta b308s: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training b308s se descarta todo su archivo
# se guardó la señal  b313l  en el directorio cleaned
# se guardó la señal  b314s  en el directorio cleaned
# se guardó la señal  b330s  en el directorio cleaned
# se guardó la señal  b331l  en el directorio cleaned
# se guardó la señal  b332s  en el directorio cleaned
# se guardó la señal  b339l  en el directorio cleaned
# se guardó la señal  b340s  en el directorio cleaned
# se guardó la señal  b341l  en el directorio cleaned
# se guardó la señal  b349l  en el directorio cleaned
# se guardó la señal  b379l  en el directorio cleaned
# se guardó la señal  b387l  en el directorio cleaned
# se guardó la señal  b388s  en el directorio cleaned
# se guardó la señal  b389l  en el directorio cleaned
# se guardó la señal  b428s  en el directorio cleaned
# se guardó la señal  b451l  en el directorio cleaned
# se guardó la señal  b455l  en el directorio cleaned
# se guardó la señal  b456s  en el directorio cleaned
# Señal corrupta b484s: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training b484s se descarta todo su archivo
# se guardó la señal  b485l  en el directorio cleaned
# se guardó la señal  b486s  en el directorio cleaned
# se guardó la señal  b487l  en el directorio cleaned
# se guardó la señal  b488s  en el directorio cleaned
# se guardó la señal  b494s  en el directorio cleaned
# se guardó la señal  b495l  en el directorio cleaned
# Señal corrupta b497l: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training b497l se descarta todo su archivo
# se guardó la señal  b515l  en el directorio cleaned
# se guardó la señal  b516s  en el directorio cleaned
# se guardó la señal  b517l  en el directorio cleaned
# Señal corrupta b528s: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training b528s se descarta todo su archivo
# se guardó la señal  b537l  en el directorio cleaned
# se guardó la señal  b538s  en el directorio cleaned
# se guardó la señal  b553l  en el directorio cleaned
# se guardó la señal  b554s  en el directorio cleaned
# Señal corrupta b560s: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training b560s se descarta todo su archivo
# Señal corrupta b561l: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training b561l se descarta todo su archivo
# Señal corrupta b562s: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training b562s se descarta todo su archivo
# se guardó la señal  b578s  en el directorio cleaned
# se guardó la señal  b587l  en el directorio cleaned
# se guardó la señal  b588s  en el directorio cleaned
# Señal corrupta b600s: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training b600s se descarta todo su archivo
# se guardó la señal  b617l  en el directorio cleaned
# se guardó la señal  b656s  en el directorio cleaned
# se guardó la señal  b659l  en el directorio cleaned
# se guardó la señal  b664s  en el directorio cleaned
# se guardó la señal  b669l  en el directorio cleaned
# se guardó la señal  b672s  en el directorio cleaned
# se guardó la señal  b681l  en el directorio cleaned
# se guardó la señal  b684s  en el directorio cleaned
# se guardó la señal  b685l  en el directorio cleaned
# Señal corrupta b695l: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training b695l se descarta todo su archivo
# se guardó la señal  b703l  en el directorio cleaned
# Señal corrupta b706s: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training b706s se descarta todo su archivo
# se guardó la señal  b708s  en el directorio cleaned
# se guardó la señal  b722s  en el directorio cleaned
# se guardó la señal  b730s  en el directorio cleaned
# se guardó la señal  b734s  en el directorio cleaned
# se guardó la señal  b753l  en el directorio cleaned
# se guardó la señal  b757l  en el directorio cleaned
# se guardó la señal  b764s  en el directorio cleaned
# Señal corrupta b794s: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training b794s se descarta todo su archivo
# se guardó la señal  b820s  en el directorio cleaned
# se guardó la señal  b824s  en el directorio cleaned
# se guardó la señal  b832s  en el directorio cleaned
# Señal corrupta b835l: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training b835l se descarta todo su archivo
# se guardó la señal  b838s  en el directorio cleaned
# se guardó la señal  b839l  en el directorio cleaned
# se guardó la señal  b840s  en el directorio cleaned
# se guardó la señal  b841l  en el directorio cleaned
# Señal corrupta b849l: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training b849l se descarta todo su archivo
# se guardó la señal  f120s  en el directorio cleaned
# se guardó la señal  f121l  en el directorio cleaned
# se guardó la señal  f129l  en el directorio cleaned
# se guardó la señal  f130s  en el directorio cleaned
# se guardó la señal  f137l  en el directorio cleaned
# se guardó la señal  f138s  en el directorio cleaned
# se guardó la señal  f144s  en el directorio cleaned
# se guardó la señal  f189l  en el directorio cleaned
# se guardó la señal  f190s  en el directorio cleaned
# se guardó la señal  f196s  en el directorio cleaned
# se guardó la señal  f236s  en el directorio cleaned
# se guardó la señal  f237l  en el directorio cleaned
# se guardó la señal  f260s  en el directorio cleaned
# se guardó la señal  f261l  en el directorio cleaned
# se guardó la señal  f281l  en el directorio cleaned
# se guardó la señal  f304s  en el directorio cleaned
# se guardó la señal  f321l  en el directorio cleaned
# se guardó la señal  f346s  en el directorio cleaned
# se guardó la señal  f352s  en el directorio cleaned
# se guardó la señal  f362s  en el directorio cleaned
# se guardó la señal  f407l  en el directorio cleaned
# se guardó la señal  f408s  en el directorio cleaned
# se guardó la señal  f414s  en el directorio cleaned
# se guardó la señal  f415l  en el directorio cleaned
# Señal corrupta f440s: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training f440s se descarta todo su archivo
# se guardó la señal  f441l  en el directorio cleaned
# se guardó la señal  f450s  en el directorio cleaned
# se guardó la señal  f474s  en el directorio cleaned
# se guardó la señal  f493l  en el directorio cleaned
# se guardó la señal  f499l  en el directorio cleaned
# se guardó la señal  f500s  en el directorio cleaned
# Señal corrupta f529l: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training f529l se descarta todo su archivo
# Señal corrupta f530s: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training f530s se descarta todo su archivo
# se guardó la señal  f543l  en el directorio cleaned
# se guardó la señal  f544s  en el directorio cleaned
# se guardó la señal  f545l  en el directorio cleaned
# se guardó la señal  f563l  en el directorio cleaned
# se guardó la señal  f572s  en el directorio cleaned
# Señal corrupta f576s: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training f576s se descarta todo su archivo
# se guardó la señal  f586s  en el directorio cleaned
# se guardó la señal  f592s  en el directorio cleaned
# se guardó la señal  f593l  en el directorio cleaned
# se guardó la señal  f602s  en el directorio cleaned
# se guardó la señal  f605l  en el directorio cleaned
# Señal corrupta f610s: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training f610s se descarta todo su archivo
# se guardó la señal  f613l  en el directorio cleaned
# se guardó la señal  f618s  en el directorio cleaned
# se guardó la señal  f637l  en el directorio cleaned
# se guardó la señal  f642s  en el directorio cleaned
# se guardó la señal  f657l  en el directorio cleaned
# se guardó la señal  f691l  en el directorio cleaned
# se guardó la señal  f697l  en el directorio cleaned
# se guardó la señal  f751l  en el directorio cleaned
# se guardó la señal  f768s  en el directorio cleaned
# Señal corrupta f789l: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training f789l se descarta todo su archivo
# se guardó la señal  f792s  en el directorio cleaned
# Señal corrupta f799l: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training f799l se descarta todo su archivo
# se guardó la señal  f829l  en el directorio cleaned
# Señal corrupta t106s: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training t106s se descarta todo su archivo
# se guardó la señal  t107l  en el directorio cleaned
# se guardó la señal  t108s  en el directorio cleaned
# se guardó la señal  t110s  en el directorio cleaned
# se guardó la señal  t112s  en el directorio cleaned
# Señal corrupta t114s: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training t114s se descarta todo su archivo
# se guardó la señal  t116s  en el directorio cleaned
# se guardó la señal  t117l  en el directorio cleaned
# se guardó la señal  t118s  en el directorio cleaned
# se guardó la señal  t149l  en el directorio cleaned
# se guardó la señal  t150s  en el directorio cleaned
# se guardó la señal  t151l  en el directorio cleaned
# se guardó la señal  t156s  en el directorio cleaned
# se guardó la señal  t157l  en el directorio cleaned
# se guardó la señal  t173l  en el directorio cleaned
# se guardó la señal  t174s  en el directorio cleaned
# se guardó la señal  t175l  en el directorio cleaned
# se guardó la señal  t191l  en el directorio cleaned
# se guardó la señal  t192s  en el directorio cleaned
# se guardó la señal  t193l  en el directorio cleaned
# se guardó la señal  t195l  en el directorio cleaned
# se guardó la señal  t208s  en el directorio cleaned
# se guardó la señal  t209l  en el directorio cleaned
# se guardó la señal  t213l  en el directorio cleaned
# se guardó la señal  t214s  en el directorio cleaned
# se guardó la señal  t234s  en el directorio cleaned
# Señal corrupta t235l: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training t235l se descarta todo su archivo
# se guardó la señal  t238s  en el directorio cleaned
# se guardó la señal  t240s  en el directorio cleaned
# Señal corrupta t249l: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training t249l se descarta todo su archivo
# se guardó la señal  t251l  en el directorio cleaned
# se guardó la señal  t252s  en el directorio cleaned
# se guardó la señal  t263l  en el directorio cleaned
# se guardó la señal  t264s  en el directorio cleaned
# se guardó la señal  t270s  en el directorio cleaned
# se guardó la señal  t276s  en el directorio cleaned
# se guardó la señal  t277l  en el directorio cleaned
# se guardó la señal  t284s  en el directorio cleaned
# se guardó la señal  t300s  en el directorio cleaned
# se guardó la señal  t305l  en el directorio cleaned
# se guardó la señal  t320s  en el directorio cleaned
# se guardó la señal  t333l  en el directorio cleaned
# se guardó la señal  t335l  en el directorio cleaned
# se guardó la señal  t342s  en el directorio cleaned
# se guardó la señal  t343l  en el directorio cleaned
# se guardó la señal  t344s  en el directorio cleaned
# se guardó la señal  t350s  en el directorio cleaned
# se guardó la señal  t351l  en el directorio cleaned
# se guardó la señal  t356s  en el directorio cleaned
# se guardó la señal  t357l  en el directorio cleaned
# se guardó la señal  t358s  en el directorio cleaned
# se guardó la señal  t383l  en el directorio cleaned
# se guardó la señal  t384s  en el directorio cleaned
# se guardó la señal  t393l  en el directorio cleaned
# se guardó la señal  t394s  en el directorio cleaned
# se guardó la señal  t406s  en el directorio cleaned
# se guardó la señal  t409l  en el directorio cleaned
# se guardó la señal  t410s  en el directorio cleaned
# Señal corrupta t411l: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training t411l se descarta todo su archivo
# Señal corrupta t412s: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training t412s se descarta todo su archivo
# se guardó la señal  t413l  en el directorio cleaned
# se guardó la señal  t416s  en el directorio cleaned
# se guardó la señal  t417l  en el directorio cleaned
# se guardó la señal  t418s  en el directorio cleaned
# se guardó la señal  t424s  en el directorio cleaned
# se guardó la señal  t425l  en el directorio cleaned
# se guardó la señal  t430s  en el directorio cleaned
# se guardó la señal  t434s  en el directorio cleaned
# se guardó la señal  t444s  en el directorio cleaned
# se guardó la señal  t445l  en el directorio cleaned
# se guardó la señal  t447l  en el directorio cleaned
# se guardó la señal  t458s  en el directorio cleaned
# se guardó la señal  t467l  en el directorio cleaned
# se guardó la señal  t468s  en el directorio cleaned
# se guardó la señal  t469l  en el directorio cleaned
# se guardó la señal  t477l  en el directorio cleaned
# se guardó la señal  t478s  en el directorio cleaned
# Señal corrupta t496s: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training t496s se descarta todo su archivo
# se guardó la señal  t503l  en el directorio cleaned
# se guardó la señal  t504s  en el directorio cleaned
# Señal corrupta t506s: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training t506s se descarta todo su archivo
# Señal corrupta t507l: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training t507l se descarta todo su archivo
# se guardó la señal  t508s  en el directorio cleaned
# se guardó la señal  t509l  en el directorio cleaned
# se guardó la señal  t520s  en el directorio cleaned
# se guardó la señal  t521l  en el directorio cleaned
# se guardó la señal  t524s  en el directorio cleaned
# se guardó la señal  t546s  en el directorio cleaned
# se guardó la señal  t547l  en el directorio cleaned
# se guardó la señal  t565l  en el directorio cleaned
# se guardó la señal  t567l  en el directorio cleaned
# se guardó la señal  t577l  en el directorio cleaned
# se guardó la señal  t580s  en el directorio cleaned
# se guardó la señal  t589l  en el directorio cleaned
# se guardó la señal  t594s  en el directorio cleaned
# se guardó la señal  t595l  en el directorio cleaned
# se guardó la señal  t614s  en el directorio cleaned
# se guardó la señal  t622s  en el directorio cleaned
# se guardó la señal  t662s  en el directorio cleaned
# se guardó la señal  t665l  en el directorio cleaned
# se guardó la señal  t677l  en el directorio cleaned
# se guardó la señal  t678s  en el directorio cleaned
# se guardó la señal  t679l  en el directorio cleaned
# se guardó la señal  t680s  en el directorio cleaned
# se guardó la señal  t683l  en el directorio cleaned
# se guardó la señal  t688s  en el directorio cleaned
# se guardó la señal  t689l  en el directorio cleaned
# se guardó la señal  t690s  en el directorio cleaned
# se guardó la señal  t693l  en el directorio cleaned
# se guardó la señal  t698s  en el directorio cleaned
# se guardó la señal  t700s  en el directorio cleaned
# se guardó la señal  t702s  en el directorio cleaned
# se guardó la señal  t707l  en el directorio cleaned
# se guardó la señal  t709l  en el directorio cleaned
# se guardó la señal  t716s  en el directorio cleaned
# se guardó la señal  t717l  en el directorio cleaned
# Señal corrupta t719l: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training t719l se descarta todo su archivo
# se guardó la señal  t731l  en el directorio cleaned
# se guardó la señal  t737l  en el directorio cleaned
# se guardó la señal  t739l  en el directorio cleaned
# se guardó la señal  t741l  en el directorio cleaned
# se guardó la señal  t742s  en el directorio cleaned
# se guardó la señal  t744s  en el directorio cleaned
# se guardó la señal  t745l  en el directorio cleaned
# se guardó la señal  t747l  en el directorio cleaned
# se guardó la señal  t752s  en el directorio cleaned
# se guardó la señal  t755l  en el directorio cleaned
# se guardó la señal  t760s  en el directorio cleaned
# se guardó la señal  t762s  en el directorio cleaned
# se guardó la señal  t771l  en el directorio cleaned
# se guardó la señal  t777l  en el directorio cleaned
# se guardó la señal  t786s  en el directorio cleaned
# se guardó la señal  t787l  en el directorio cleaned
# se guardó la señal  t790s  en el directorio cleaned
# se guardó la señal  t800s  en el directorio cleaned
# se guardó la señal  t801l  en el directorio cleaned
# se guardó la señal  t812s  en el directorio cleaned
# se guardó la señal  t816s  en el directorio cleaned
# se guardó la señal  t817l  en el directorio cleaned
# se guardó la señal  t821l  en el directorio cleaned
# se guardó la señal  v100s  en el directorio cleaned
# se guardó la señal  v101l  en el directorio cleaned
# se guardó la señal  v102s  en el directorio cleaned
# se guardó la señal  v111l  en el directorio cleaned
# se guardó la señal  v113l  en el directorio cleaned
# se guardó la señal  v115l  en el directorio cleaned
# se guardó la señal  v119l  en el directorio cleaned
# se guardó la señal  v122s  en el directorio cleaned
# se guardó la señal  v127l  en el directorio cleaned
# se guardó la señal  v128s  en el directorio cleaned
# se guardó la señal  v131l  en el directorio cleaned
# se guardó la señal  v132s  en el directorio cleaned
# se guardó la señal  v133l  en el directorio cleaned
# se guardó la señal  v135l  en el directorio cleaned
# se guardó la señal  v136s  en el directorio cleaned
# se guardó la señal  v139l  en el directorio cleaned
# se guardó la señal  v140s  en el directorio cleaned
# se guardó la señal  v141l  en el directorio cleaned
# se guardó la señal  v143l  en el directorio cleaned
# se guardó la señal  v146s  en el directorio cleaned
# se guardó la señal  v147l  en el directorio cleaned
# se guardó la señal  v148s  en el directorio cleaned
# Señal corrupta v153l: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training v153l se descarta todo su archivo
# se guardó la señal  v154s  en el directorio cleaned
# Señal corrupta v155l: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training v155l se descarta todo su archivo
# se guardó la señal  v158s  en el directorio cleaned
# se guardó la señal  v159l  en el directorio cleaned
# se guardó la señal  v160s  en el directorio cleaned
# se guardó la señal  v162s  en el directorio cleaned
# se guardó la señal  v164s  en el directorio cleaned
# se guardó la señal  v166s  en el directorio cleaned
# se guardó la señal  v168s  en el directorio cleaned
# se guardó la señal  v169l  en el directorio cleaned
# se guardó la señal  v176s  en el directorio cleaned
# se guardó la señal  v177l  en el directorio cleaned
# Señal corrupta v179l: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training v179l se descarta todo su archivo
# se guardó la señal  v180s  en el directorio cleaned
# se guardó la señal  v181l  en el directorio cleaned
# se guardó la señal  v182s  en el directorio cleaned
# se guardó la señal  v188s  en el directorio cleaned
# se guardó la señal  v194s  en el directorio cleaned
# se guardó la señal  v197l  en el directorio cleaned
# se guardó la señal  v198s  en el directorio cleaned
# se guardó la señal  v199l  en el directorio cleaned
# Señal corrupta v200s: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training v200s se descarta todo su archivo
# se guardó la señal  v201l  en el directorio cleaned
# se guardó la señal  v202s  en el directorio cleaned
# se guardó la señal  v204s  en el directorio cleaned
# se guardó la señal  v205l  en el directorio cleaned
# se guardó la señal  v206s  en el directorio cleaned
# se guardó la señal  v207l  en el directorio cleaned
# se guardó la señal  v210s  en el directorio cleaned
# se guardó la señal  v211l  en el directorio cleaned
# se guardó la señal  v212s  en el directorio cleaned
# se guardó la señal  v217l  en el directorio cleaned
# se guardó la señal  v218s  en el directorio cleaned
# se guardó la señal  v221l  en el directorio cleaned
# se guardó la señal  v222s  en el directorio cleaned
# se guardó la señal  v224s  en el directorio cleaned
# se guardó la señal  v230s  en el directorio cleaned
# se guardó la señal  v232s  en el directorio cleaned
# se guardó la señal  v233l  en el directorio cleaned
# se guardó la señal  v241l  en el directorio cleaned
# se guardó la señal  v242s  en el directorio cleaned
# se guardó la señal  v243l  en el directorio cleaned
# se guardó la señal  v244s  en el directorio cleaned
# Señal corrupta v245l: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training v245l se descarta todo su archivo
# se guardó la señal  v246s  en el directorio cleaned
# se guardó la señal  v247l  en el directorio cleaned
# se guardó la señal  v248s  en el directorio cleaned
# se guardó la señal  v250s  en el directorio cleaned
# se guardó la señal  v253l  en el directorio cleaned
# se guardó la señal  v254s  en el directorio cleaned
# se guardó la señal  v255l  en el directorio cleaned
# se guardó la señal  v256s  en el directorio cleaned
# se guardó la señal  v257l  en el directorio cleaned
# se guardó la señal  v258s  en el directorio cleaned
# se guardó la señal  v259l  en el directorio cleaned
# se guardó la señal  v262s  en el directorio cleaned
# se guardó la señal  v271l  en el directorio cleaned
# se guardó la señal  v274s  en el directorio cleaned
# se guardó la señal  v275l  en el directorio cleaned
# se guardó la señal  v280s  en el directorio cleaned
# se guardó la señal  v282s  en el directorio cleaned
# se guardó la señal  v283l  en el directorio cleaned
# se guardó la señal  v289l  en el directorio cleaned
# se guardó la señal  v290s  en el directorio cleaned
# se guardó la señal  v291l  en el directorio cleaned
# se guardó la señal  v292s  en el directorio cleaned
# se guardó la señal  v293l  en el directorio cleaned
# se guardó la señal  v294s  en el directorio cleaned
# se guardó la señal  v295l  en el directorio cleaned
# se guardó la señal  v296s  en el directorio cleaned
# se guardó la señal  v298s  en el directorio cleaned
# se guardó la señal  v303l  en el directorio cleaned
# Señal corrupta v307l: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training v307l se descarta todo su archivo
# se guardó la señal  v309l  en el directorio cleaned
# se guardó la señal  v312s  en el directorio cleaned
# se guardó la señal  v316s  en el directorio cleaned
# se guardó la señal  v317l  en el directorio cleaned
# se guardó la señal  v318s  en el directorio cleaned
# se guardó la señal  v319l  en el directorio cleaned
# se guardó la señal  v322s  en el directorio cleaned
# se guardó la señal  v323l  en el directorio cleaned
# se guardó la señal  v324s  en el directorio cleaned
# se guardó la señal  v325l  en el directorio cleaned
# se guardó la señal  v326s  en el directorio cleaned
# se guardó la señal  v327l  en el directorio cleaned
# se guardó la señal  v328s  en el directorio cleaned
# se guardó la señal  v329l  en el directorio cleaned
# se guardó la señal  v334s  en el directorio cleaned
# se guardó la señal  v336s  en el directorio cleaned
# se guardó la señal  v337l  en el directorio cleaned
# se guardó la señal  v338s  en el directorio cleaned
# Señal corrupta v347l: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training v347l se descarta todo su archivo
# se guardó la señal  v348s  en el directorio cleaned
# se guardó la señal  v353l  en el directorio cleaned
# se guardó la señal  v354s  en el directorio cleaned
# se guardó la señal  v355l  en el directorio cleaned
# se guardó la señal  v359l  en el directorio cleaned
# se guardó la señal  v360s  en el directorio cleaned
# se guardó la señal  v361l  en el directorio cleaned
# se guardó la señal  v364s  en el directorio cleaned
# se guardó la señal  v365l  en el directorio cleaned
# Señal corrupta v366s: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training v366s se descarta todo su archivo
# se guardó la señal  v367l  en el directorio cleaned
# se guardó la señal  v368s  en el directorio cleaned
# se guardó la señal  v369l  en el directorio cleaned
# se guardó la señal  v370s  en el directorio cleaned
# se guardó la señal  v371l  en el directorio cleaned
# se guardó la señal  v373l  en el directorio cleaned
# se guardó la señal  v374s  en el directorio cleaned
# se guardó la señal  v375l  en el directorio cleaned
# se guardó la señal  v380s  en el directorio cleaned
# se guardó la señal  v381l  en el directorio cleaned
# se guardó la señal  v390s  en el directorio cleaned
# se guardó la señal  v392s  en el directorio cleaned
# se guardó la señal  v395l  en el directorio cleaned
# se guardó la señal  v398s  en el directorio cleaned
# se guardó la señal  v399l  en el directorio cleaned
# Señal corrupta v400s: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training v400s se descarta todo su archivo
# se guardó la señal  v401l  en el directorio cleaned
# se guardó la señal  v402s  en el directorio cleaned
# se guardó la señal  v403l  en el directorio cleaned
# se guardó la señal  v404s  en el directorio cleaned
# se guardó la señal  v405l  en el directorio cleaned
# se guardó la señal  v419l  en el directorio cleaned
# se guardó la señal  v421l  en el directorio cleaned
# se guardó la señal  v423l  en el directorio cleaned
# se guardó la señal  v426s  en el directorio cleaned
# se guardó la señal  v427l  en el directorio cleaned
# se guardó la señal  v431l  en el directorio cleaned
# se guardó la señal  v432s  en el directorio cleaned
# se guardó la señal  v433l  en el directorio cleaned
# se guardó la señal  v437l  en el directorio cleaned
# se guardó la señal  v438s  en el directorio cleaned
# se guardó la señal  v448s  en el directorio cleaned
# se guardó la señal  v452s  en el directorio cleaned
# se guardó la señal  v453l  en el directorio cleaned
# se guardó la señal  v454s  en el directorio cleaned
# se guardó la señal  v459l  en el directorio cleaned
# se guardó la señal  v460s  en el directorio cleaned
# Señal corrupta v463l: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training v463l se descarta todo su archivo
# se guardó la señal  v464s  en el directorio cleaned
# se guardó la señal  v466s  en el directorio cleaned
# se guardó la señal  v470s  en el directorio cleaned
# se guardó la señal  v471l  en el directorio cleaned
# se guardó la señal  v472s  en el directorio cleaned
# se guardó la señal  v473l  en el directorio cleaned
# se guardó la señal  v475l  en el directorio cleaned
# se guardó la señal  v476s  en el directorio cleaned
# Señal corrupta v479l: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training v479l se descarta todo su archivo
# se guardó la señal  v480s  en el directorio cleaned
# se guardó la señal  v481l  en el directorio cleaned
# se guardó la señal  v482s  en el directorio cleaned
# se guardó la señal  v483l  en el directorio cleaned
# Señal corrupta v489l: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training v489l se descarta todo su archivo
# se guardó la señal  v491l  en el directorio cleaned
# se guardó la señal  v492s  en el directorio cleaned
# se guardó la señal  v498s  en el directorio cleaned
# se guardó la señal  v501l  en el directorio cleaned
# se guardó la señal  v502s  en el directorio cleaned
# se guardó la señal  v505l  en el directorio cleaned
# se guardó la señal  v510s  en el directorio cleaned
# Señal corrupta v511l: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training v511l se descarta todo su archivo
# se guardó la señal  v513l  en el directorio cleaned
# se guardó la señal  v518s  en el directorio cleaned
# se guardó la señal  v519l  en el directorio cleaned
# se guardó la señal  v522s  en el directorio cleaned
# se guardó la señal  v523l  en el directorio cleaned
# se guardó la señal  v525l  en el directorio cleaned
# se guardó la señal  v531l  en el directorio cleaned
# se guardó la señal  v532s  en el directorio cleaned
# se guardó la señal  v533l  en el directorio cleaned
# se guardó la señal  v534s  en el directorio cleaned
# se guardó la señal  v535l  en el directorio cleaned
# se guardó la señal  v536s  en el directorio cleaned
# se guardó la señal  v540s  en el directorio cleaned
# se guardó la señal  v541l  en el directorio cleaned
# se guardó la señal  v542s  en el directorio cleaned
# se guardó la señal  v548s  en el directorio cleaned
# se guardó la señal  v549l  en el directorio cleaned
# se guardó la señal  v551l  en el directorio cleaned
# se guardó la señal  v552s  en el directorio cleaned
# se guardó la señal  v557l  en el directorio cleaned
# se guardó la señal  v559l  en el directorio cleaned
# se guardó la señal  v564s  en el directorio cleaned
# se guardó la señal  v566s  en el directorio cleaned
# se guardó la señal  v568s  en el directorio cleaned
# se guardó la señal  v569l  en el directorio cleaned
# se guardó la señal  v570s  en el directorio cleaned
# se guardó la señal  v571l  en el directorio cleaned
# se guardó la señal  v573l  en el directorio cleaned
# se guardó la señal  v574s  en el directorio cleaned
# se guardó la señal  v575l  en el directorio cleaned
# se guardó la señal  v579l  en el directorio cleaned
# se guardó la señal  v581l  en el directorio cleaned
# se guardó la señal  v583l  en el directorio cleaned
# se guardó la señal  v585l  en el directorio cleaned
# se guardó la señal  v590s  en el directorio cleaned
# se guardó la señal  v596s  en el directorio cleaned
# se guardó la señal  v597l  en el directorio cleaned
# se guardó la señal  v598s  en el directorio cleaned
# se guardó la señal  v601l  en el directorio cleaned
# se guardó la señal  v607l  en el directorio cleaned
# Señal corrupta v609l: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training v609l se descarta todo su archivo
# se guardó la señal  v611l  en el directorio cleaned
# se guardó la señal  v612s  en el directorio cleaned
# se guardó la señal  v615l  en el directorio cleaned
# se guardó la señal  v616s  en el directorio cleaned
# se guardó la señal  v619l  en el directorio cleaned
# se guardó la señal  v620s  en el directorio cleaned
# Señal corrupta v621l: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training v621l se descarta todo su archivo
# Señal corrupta v623l: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training v623l se descarta todo su archivo
# se guardó la señal  v625l  en el directorio cleaned
# se guardó la señal  v626s  en el directorio cleaned
# se guardó la señal  v627l  en el directorio cleaned
# se guardó la señal  v628s  en el directorio cleaned
# se guardó la señal  v629l  en el directorio cleaned
# se guardó la señal  v630s  en el directorio cleaned
# se guardó la señal  v632s  en el directorio cleaned
# se guardó la señal  v633l  en el directorio cleaned
# se guardó la señal  v634s  en el directorio cleaned
# se guardó la señal  v635l  en el directorio cleaned
# se guardó la señal  v636s  en el directorio cleaned
# se guardó la señal  v638s  en el directorio cleaned
# se guardó la señal  v640s  en el directorio cleaned
# se guardó la señal  v641l  en el directorio cleaned
# se guardó la señal  v643l  en el directorio cleaned
# se guardó la señal  v644s  en el directorio cleaned
# se guardó la señal  v646s  en el directorio cleaned
# se guardó la señal  v647l  en el directorio cleaned
# se guardó la señal  v648s  en el directorio cleaned
# se guardó la señal  v649l  en el directorio cleaned
# se guardó la señal  v652s  en el directorio cleaned
# se guardó la señal  v655l  en el directorio cleaned
# se guardó la señal  v658s  en el directorio cleaned
# se guardó la señal  v660s  en el directorio cleaned
# se guardó la señal  v663l  en el directorio cleaned
# se guardó la señal  v666s  en el directorio cleaned
# se guardó la señal  v671l  en el directorio cleaned
# se guardó la señal  v674s  en el directorio cleaned
# se guardó la señal  v676s  en el directorio cleaned
# se guardó la señal  v682s  en el directorio cleaned
# se guardó la señal  v686s  en el directorio cleaned
# se guardó la señal  v687l  en el directorio cleaned
# se guardó la señal  v692s  en el directorio cleaned
# se guardó la señal  v696s  en el directorio cleaned
# se guardó la señal  v701l  en el directorio cleaned
# se guardó la señal  v704s  en el directorio cleaned
# se guardó la señal  v710s  en el directorio cleaned
# se guardó la señal  v711l  en el directorio cleaned
# se guardó la señal  v713l  en el directorio cleaned
# se guardó la señal  v714s  en el directorio cleaned
# se guardó la señal  v718s  en el directorio cleaned
# se guardó la señal  v720s  en el directorio cleaned
# se guardó la señal  v721l  en el directorio cleaned
# se guardó la señal  v724s  en el directorio cleaned
# se guardó la señal  v725l  en el directorio cleaned
# se guardó la señal  v726s  en el directorio cleaned
# Señal corrupta v727l: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training v727l se descarta todo su archivo
# se guardó la señal  v728s  en el directorio cleaned
# se guardó la señal  v729l  en el directorio cleaned
# se guardó la señal  v732s  en el directorio cleaned
# se guardó la señal  v733l  en el directorio cleaned
# se guardó la señal  v736s  en el directorio cleaned
# se guardó la señal  v738s  en el directorio cleaned
# Señal corrupta v743l: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training v743l se descarta todo su archivo
# se guardó la señal  v748s  en el directorio cleaned
# se guardó la señal  v749l  en el directorio cleaned
# se guardó la señal  v756s  en el directorio cleaned
# se guardó la señal  v758s  en el directorio cleaned
# se guardó la señal  v759l  en el directorio cleaned
# se guardó la señal  v761l  en el directorio cleaned
# se guardó la señal  v763l  en el directorio cleaned
# se guardó la señal  v765l  en el directorio cleaned
# se guardó la señal  v766s  en el directorio cleaned
# se guardó la señal  v767l  en el directorio cleaned
# se guardó la señal  v769l  en el directorio cleaned
# se guardó la señal  v770s  en el directorio cleaned
# se guardó la señal  v772s  en el directorio cleaned
# se guardó la señal  v773l  en el directorio cleaned
# Señal corrupta v774s: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training v774s se descarta todo su archivo
# Señal corrupta v775l: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training v775l se descarta todo su archivo
# se guardó la señal  v779l  en el directorio cleaned
# se guardó la señal  v781l  en el directorio cleaned
# se guardó la señal  v782s  en el directorio cleaned
# se guardó la señal  v783l  en el directorio cleaned
# se guardó la señal  v784s  en el directorio cleaned
# se guardó la señal  v788s  en el directorio cleaned
# se guardó la señal  v791l  en el directorio cleaned
# se guardó la señal  v793l  en el directorio cleaned
# se guardó la señal  v795l  en el directorio cleaned
# se guardó la señal  v797l  en el directorio cleaned
# se guardó la señal  v803l  en el directorio cleaned
# se guardó la señal  v804s  en el directorio cleaned
# se guardó la señal  v805l  en el directorio cleaned
# se guardó la señal  v806s  en el directorio cleaned
# se guardó la señal  v808s  en el directorio cleaned
# Señal corrupta v809l: Señal no califica para ser del training, no contiene ecg limpias
# Señal no califica para ser del training v809l se descarta todo su archivo
# se guardó la señal  v811l  en el directorio cleaned
# se guardó la señal  v813l  en el directorio cleaned
# se guardó la señal  v814s  en el directorio cleaned
# se guardó la señal  v815l  en el directorio cleaned
# se guardó la señal  v818s  en el directorio cleaned
# se guardó la señal  v823l  en el directorio cleaned
# se guardó la señal  v826s  en el directorio cleaned
# se guardó la señal  v827l  en el directorio cleaned
# se guardó la señal  v828s  en el directorio cleaned
# se guardó la señal  v830s  en el directorio cleaned
# se guardó la señal  v831l  en el directorio cleaned
# se guardó la señal  v833l  en el directorio cleaned
# se guardó la señal  v834s  en el directorio cleaned
# se guardó la señal  v836s  en el directorio cleaned
# se guardó la señal  v837l  en el directorio cleaned
# se guardó la señal  v842s  en el directorio cleaned
# se guardó la señal  v843l  en el directorio cleaned
# se guardó la señal  v844s  en el directorio cleaned
# se guardó la señal  v845l  en el directorio cleaned
# se guardó la señal  v846s  en el directorio cleaned
# se guardó la señal  v848s  en el directorio cleaned

# %%
# Se revisa cuántas señales se guardaron en el directorio cleaned
i=0
for file in os.listdir('data/cleaned/'):
    if file.endswith('.mat'):
        i += 1
print('cantidad de datos válidos para training:', i)
# Out:
# cantidad de datos válidos para training: 655

# %% [markdown]
# Una vez se tienen los datos válidos se corroboran sus características, cabe destacar que aún no están limpios

# %%
# graficar una señal limpia
fileName = 'b388s'
path = 'data/cleaned/'
record = read_file_hea(fileName, 'data/training/')
signals = read_file_mat(fileName, path)
flat_areas = read_file_flat(fileName, path)
zigzag_areas = read_file_zigzag(fileName, path)
grafica_preview(record, signals, signals, path, flat_areas, zigzag_areas)

# %%
visualizador_señales_limpias(read_file_hea(fileName, 'data/training/'), read_file_mat(fileName, path))
# Out:
# Bradycardia - False alarm
# II
# V
# PLETH
# ABP

# %% [markdown]
# ### 3.2.2.2 Preparación de los datos calificados
#
#
# **Limpieza de los datos válidos**
#
# Los canales considerados para el análisis, sólo corresponden a derivaciones ECG y PPG, por lo que son los únicos que se van a analizar.
#
# Se utiliza la librería [Biosspy](https://biosppy.readthedocs.io/en/stable/) para la limpieza, normalización de los datos y extracción de características, junto con un filtro de paso de banda. Posterior a esto se extraen las caracteristicas de cada caso y se guardan los canales ECG y PPG en un vector de canales

# %%
from scipy.signal import savgol_filter

# retorna los datos necesarios y limpios de cada caso
def biosppy_cases_data(new_path, old_path, nameFiles):

    data_cases = []
    
    for fileName in nameFiles:

        signals = read_file_mat(fileName, new_path)
        record = read_file_hea(fileName, old_path)

        # Se aplica filtro sólo a las señales ECG ('I', 'II', 'III' y 'V') y PLETH
        ecg_type = ['I', 'II', 'III', 'V']
        pleth_type = ['PLETH']
        
        allSignals = []
        
        channel_type = []
        anomaly_type= record.comments[0]
        alarm_veracity = record.comments[1]

        min_heart_rate_pleth = 0
        max_heart_rate_pleth = 0
        min_heart_rate_ecg = 0
        max_heart_rate_ecg = 0

        for i in range(len(record.sig_name)): 
            ecg_if = (record.sig_name[i] in ecg_type)
            pleth_if = (record.sig_name[i] in pleth_type)
            if ecg_if or pleth_if:
                
                if ecg_if:
                    try:
                        channel = signals[i, :]
                        butterFilter = butter_bandpass_filter(channel, cutoff=1, fs=250, order=2)
                        channel = channel - butterFilter
                        
                        channel = ecg.ecg(signal=channel, sampling_rate=250, show=False)
                        channel_type = record.sig_name[i]

                        heart_rate_ecg = channel['heart_rate']

                        if heart_rate_ecg.any() and min_heart_rate_ecg == 0:
                            min_heart_rate_ecg = min(heart_rate_ecg)
                        if heart_rate_ecg.any() and max_heart_rate_ecg == 0:
                            max_heart_rate_ecg = max(heart_rate_ecg)
                            
                        allSignals.append([channel, channel_type])
                    except Exception as e:
                        print(f'canal {record.sig_name[i]} en señal {fileName} no válido para biosppy: {e}')
                    
                elif pleth_if:
                    
                    try:

                        channel = signals[i, :]
                        channel = ppg.ppg(signal=channel, sampling_rate=250, show=False)
                        
                        filtered_channel = channel['filtered']
                        channel_type = record.sig_name[i]

                        peaks = channel['peaks']
                        heart_rate_pleth = channel['heart_rate']

                        if heart_rate_pleth.any():
                            min_heart_rate_pleth = min(heart_rate_pleth)
                        if heart_rate_pleth.any():
                            max_heart_rate_pleth= max(heart_rate_pleth)

                        allSignals.append([channel, channel_type])

                    except Exception as e:
                        print(f'canal {record.sig_name[i]} en señal {fileName} no válido para biosppy: {e}')
        data_cases.append({'fileName:': fileName, 'channels': allSignals,'alarm_veracity': alarm_veracity, 'anomaly_type': anomaly_type, 'max_heart_rate_ecg': max_heart_rate_ecg, 'min_heart_rate_ecg': min_heart_rate_ecg, 'max_heart_rate_pleth': max_heart_rate_pleth, 'min_heart_rate_pleth': min_heart_rate_pleth})

    return data_cases

# %%
new_path = 'data/cleaned/'
nameFiles = get_name_files(new_path,'.mat')


all_unique_comments_anomaly = set()
for file in nameFiles:
    record = read_file_hea(file, old_path)
    all_unique_comments_anomaly.update(record.comments[0].split())

print(f"Tipos de arritmia presentes: {all_unique_comments_anomaly}")
print(f"Total: {len(all_unique_comments_anomaly)}")
# Out:
# Tipos de arritmia presentes: {'Asystole', 'Ventricular_Flutter_Fib', 'Tachycardia', 'Ventricular_Tachycardia', 'Bradycardia'}
# Total: 5

# %% [markdown]
# # 3.3 Desarrollo de algoritmos
#
#
# Se puede observar que al limpiar la señal, se descartan las señales PLETH y ECG que, o no poseen suficientes pulsos para detectar el ritmo cardiaco o poseen anomalías en su señal que no permiten extraer sus características incluso con los filtros aplicados.
# Luego se convierten las señales válidas en un DataFrame de la librería [Pandas](https://pandas.pydata.org)

# %%
data_cases = biosppy_cases_data(new_path, old_path, nameFiles)
data_cases = pd.DataFrame(data_cases)
# Out:
# canal PLETH en señal a185l no válido para biosppy: index 0 is out of bounds for axis 0 with size 0
# canal PLETH en señal a372s no válido para biosppy: index 0 is out of bounds for axis 0 with size 0
# canal II en señal a699l no válido para biosppy: Not enough beats to compute heart rate.
# canal PLETH en señal b387l no válido para biosppy: index 0 is out of bounds for axis 0 with size 0
# canal PLETH en señal f450s no válido para biosppy: index 0 is out of bounds for axis 0 with size 0
# canal PLETH en señal v181l no válido para biosppy: index 0 is out of bounds for axis 0 with size 0
# canal PLETH en señal v258s no válido para biosppy: index 0 is out of bounds for axis 0 with size 0
# canal PLETH en señal v399l no válido para biosppy: index 0 is out of bounds for axis 0 with size 0
# canal PLETH en señal v448s no válido para biosppy: index 0 is out of bounds for axis 0 with size 0
# canal PLETH en señal v460s no válido para biosppy: index 0 is out of bounds for axis 0 with size 0
# canal PLETH en señal v475l no válido para biosppy: index 0 is out of bounds for axis 0 with size 0
# canal PLETH en señal v531l no válido para biosppy: index 0 is out of bounds for axis 0 with size 0

# %%
data_cases
# Out:
#     fileName:                                           channels  \
# 0       a103l  [[([0.0000e+00 4.0000e-03 8.0000e-03 ... 1.998...
# 1       a104s  [[([0.0000e+00 4.0000e-03 8.0000e-03 ... 1.998...
# 2       a105l  [[([0.0000e+00 4.0000e-03 8.0000e-03 ... 1.998...
# 3       a109l  [[([0.0000e+00 4.0000e-03 8.0000e-03 ... 1.998...
# 4       a142s  [[([0.0000e+00 4.0000e-03 8.0000e-03 ... 1.998...
# ..        ...                                                ...
# 650     v842s  [[([0.0000e+00 4.0000e-03 8.0000e-03 ... 1.998...
# 651     v843l  [[([0.0000e+00 4.0000e-03 8.0000e-03 ... 1.998...
# 652     v844s  [[([0.0000e+00 4.0000e-03 8.0000e-03 ... 1.998...
# 653     v845l  [[([0.0000e+00 4.0000e-03 8.0000e-03 ... 1.998...
# 654     v848s  [[([0.0000e+00 4.0000e-03 8.0000e-03 ... 1.998...
#
#     alarm_veracity             anomaly_type  max_heart_rate_ecg  \
# 0      False alarm                 Asystole          131.209359
# 1      False alarm                 Asystole          141.534392
# 2      False alarm                 Asystole          134.732947
# 3      False alarm                 Asystole           67.615739
# 4       True alarm                 Asystole          130.835973
# ..             ...                      ...                 ...
# 650     True alarm  Ventricular_Tachycardia          127.685972
# 651    False alarm  Ventricular_Tachycardia          166.904859
# 652     True alarm  Ventricular_Tachycardia          136.363636
# 653    False alarm  Ventricular_Tachycardia          130.072953
# 654    False alarm  Ventricular_Tachycardia          134.343434
#
#      min_heart_rate_ecg  max_heart_rate_pleth  min_heart_rate_pleth
# 0            122.207487            134.906760             90.719427
# 1             68.412468            131.605955            108.133433
# 2            133.138432            151.502952             70.223670
# 3             55.351068              0.000000              0.000000
# 4            106.710343            123.048083             73.653664
# ..                  ...                   ...                   ...
# 650           79.104246              0.000000              0.000000
# 651           73.409852             76.056196             72.478331
# 652           59.607843              0.000000              0.000000
# 653           96.220563              0.000000              0.000000
# 654          113.353819            138.828650            110.635976
#
# [655 rows x 8 columns]

# %% [markdown]
# Se establece una función extra para visualizar las señales limpias con todas sus características importantes de un sólo parámetro

# %%
def visualizador_df_signals(channel):
    ecg_type = ['I', 'II', 'III', 'V']
    pleth_type = ['PLETH']
    print(channel['alarm_veracity'] + ' - ' + channel['anomaly_type'])
    if channel['channel_type'] in ecg_type:
        ecg.ecg(signal=channel['channel'], sampling_rate=250, show=True)
    elif channel['channel_type'] in pleth_type:
        ppg.ppg(signal=channel['channel'], sampling_rate=250, show=True)

# %% [markdown]
# ### 3.3.2 Algoritmos de aprendizaje para detectar Bradicardia extrema
#
# La bradicardia se considera cuando la frecuencia cardíaca es inferior a 60 lpm. En casos extremos, puede llegar a ser significativamente más baja, lo que puede comprometer la circulación sanguínea y provocar síntomas graves como mareos, desmayos y dificultad para respira. [6][2]
#
# Para detectar bradicardia es importante determinar el valor mínimo de ritmo cardiaco, que se extraen de alguna de las derivaciones ECG y ser guardan en la variable  “min_ebpm”, siendo el canal 'II' el más exacto y el priorizado en este caso. Observando [ExploraciónHea.csv](data/exploración.hea) es el primero en las etiquetas por lo que será el primero en evaluarse. También será considerado el ritmo cardiaco mínimo de canales PPG o PLETH guardadas en la variable “min_pbpm”. [2][7]
#
# Los Algortimos escogidos corresponen a SVM y RandomForest, esto debido a que están basados en vectores de características, en este caso el ritmo cardiaco mínimo detectado en la señal.

# %%
#extraer datos de bradicardia
brady_cases = pd.DataFrame()

brady_cases = data_cases[data_cases['anomaly_type'] == 'Bradycardia']
brady_cases = brady_cases.reset_index(drop=True)

# brady_cases['alarm_veracity'].value_counts()

b_true = brady_cases[brady_cases['alarm_veracity'] == 'True alarm'][0:33]
b_false = brady_cases[brady_cases['alarm_veracity'] == 'False alarm'][0:33]

b_train = pd.concat([b_true, b_false])


print(b_train)
print(b_train['alarm_veracity'].value_counts())
#agregar el filename a cada punto del plot

axes = b_true.plot(kind='scatter', x='min_heart_rate_pleth', y='min_heart_rate_ecg', color='blue', label='True')
b_false.plot(kind='scatter', x='min_heart_rate_ecg', y='min_heart_rate_pleth', color='red', label='False', ax=axes)

# for i, txt in enumerate(b_true['fileName:']):
#     axes.annotate(txt, (b_true['min_heart_rate_pleth'].iat[i], b_true['min_heart_rate_ecg'].iat[i]), fontsize=8)

# for i, txt in enumerate(b_false['fileName:']):
#     axes.annotate(txt, (b_false['min_heart_rate_ecg'].iat[i], b_false['min_heart_rate_pleth'].iat[i]), fontsize=8)
# Out:
#    fileName:                                           channels  \
# 0      b124s  [[([0.0000e+00 4.0000e-03 8.0000e-03 ... 1.998...
# 1      b125l  [[([0.0000e+00 4.0000e-03 8.0000e-03 ... 1.998...
# 2      b126s  [[([0.0000e+00 4.0000e-03 8.0000e-03 ... 1.998...
# 3      b183l  [[([0.0000e+00 4.0000e-03 8.0000e-03 ... 1.998...
# 5      b187l  [[([0.0000e+00 4.0000e-03 8.0000e-03 ... 1.998...
# ..       ...                                                ...
# 57     b685l  [[([0.0000e+00 4.0000e-03 8.0000e-03 ... 1.998...
# 58     b703l  [[([0.0000e+00 4.0000e-03 8.0000e-03 ... 1.998...
# 63     b753l  [[([0.0000e+00 4.0000e-03 8.0000e-03 ... 1.998...
# 67     b824s  [[([0.0000e+00 4.0000e-03 8.0000e-03 ... 1.998...
# 72     b841l  [[([0.0000e+00 4.0000e-03 8.0000e-03 ... 1.998...
#
#    alarm_veracity anomaly_type  max_heart_rate_ecg  min_heart_rate_ecg  \
# 0      True alarm  Bradycardia           61.894455           54.391932
# 1      True alarm  Bradycardia           68.742642           54.096871
# 2      True alarm  Bradycardia           62.970871           50.194860
# 3      True alarm  Bradycardia           93.087558           84.913480
# 5      True alarm  Bradycardia          150.897398          102.082078
# ..            ...          ...                 ...                 ...
# 57    False alarm  Bradycardia           53.128837           50.680335
# 58    False alarm  Bradycardia           77.065997           70.871802
# 63    False alarm  Bradycardia           50.285502           45.457865
# 67    False alarm  Bradycardia           58.670939           49.616401
# 72    False alarm  Bradycardia           60.080321           60.000000
#
#     max_heart_rate_pleth  min_heart_rate_pleth
# 0             108.783291             61.798205
# 1             110.220798             59.105846
# 2             106.382979             61.680391
# 3             112.336463             59.769797
# 5             148.510418             82.173825
# ..                   ...                   ...
# 57            136.221369             85.160399
# 58             85.786975             71.315730
# 63            154.983165             86.695990
# 67              0.000000              0.000000
# 72              0.000000              0.000000
#
# [66 rows x 8 columns]
# alarm_veracity
# True alarm     33
# False alarm    33
# Name: count, dtype: int64
# <Axes: xlabel='min_heart_rate_ecg', ylabel='min_heart_rate_pleth'>

# %% [markdown]
# Se observan en el gráfico tendencias interesantes, en el caso de el ritmo cardiaco mínimo de ECG, que no posee una medida en pleth, se califica como una falsa alarma. Por el contrario casos que sólo poseen medida de latido cardiaco mínimo en PLETH y no en ECG suelen ser verdaderos.
#
# ### SVM aplicación lineal básica
#
# Se aplica el algoritmo SVM que busca encontrar el mejor hiperplano que separa diferentes clases en un espacio multidimensional. Su objetivo es maximizar el margen entre las clases, lo que significa que intenta crear la mayor distancia posible entre los puntos más cercanos de cada clase y el hiperplano de separación.

# %%
feature_df= b_train[['min_heart_rate_ecg', 'min_heart_rate_pleth']]
X = np.asarray(feature_df)
y= np.asarray(b_train['alarm_veracity'])
#dividir en train y test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=4)
X_train.shape

print(X_train.shape)

classifier = svm.SVC(kernel='linear', gamma='auto', C=2)
classifier.fit(X_train, y_train)

y_predict = classifier.predict(X_test) 

print(classification_report(y_test, y_predict))
# Out:
# (52, 2)
#               precision    recall  f1-score   support
#
#  False alarm       0.50      0.40      0.44         5
#   True alarm       0.70      0.78      0.74         9
#
#     accuracy                           0.64        14
#    macro avg       0.60      0.59      0.59        14
# weighted avg       0.63      0.64      0.63        14

# %% [markdown]
# La predicción en este caso no es muy buena para detectar falsas alarmas, esto puede ser debido a la dispersión de los datos de entrenamiento o a una mala elección en el modelo, ya que no se considera la señal en si como un parámetro.
# El uso de un kernel gaussiano y no lineal podría acertar más la predicción, no fue aplicado por cuestiones de tiempo, sin embargo es la opción recomendable [2]

# %% [markdown]
# ## Random Forest

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=4)

# Initialize and train the RandomForestClassifier
clf = RandomForestClassifier(max_depth=10, random_state=1)
clf.fit(X_train, y_train)

# Predict using the test data
y_predict = clf.predict(X_test)

print(classification_report(y_test, y_predict))
# Out:
#               precision    recall  f1-score   support
#
#  False alarm       0.67      0.67      0.67         3
#   True alarm       0.75      0.75      0.75         4
#
#     accuracy                           0.71         7
#    macro avg       0.71      0.71      0.71         7
# weighted avg       0.71      0.71      0.71         7

# %% [markdown]
# En caso de Random Forest mejoran los puntajes de precición, esto debe ser porque tiene mejor capacidad de clasificación por generalización, y, observando este caso en concreto, las caracterísitcas no siguen un sólo patrón, además de que muchas muestras se encontraban superpuestas o demasiado cerca la una de la otra.
#
#
# **Justificación de las métricas**
#
# 1. Precisión
#
# La precisión mide la proporción de verdaderos positivos (TP) sobre el total de predicciones positivas (TP + FP). En el contexto de un problema con alarmas (falsas y verdaderas), una alta precisión indica que cuando el modelo predice una "alarma verdadera", es probable que sea correcta. Esto es crucial en aplicaciones donde las falsas alarmas pueden tener costos altos, como en sistemas de seguridad o diagnósticos médicos.[8]
#
# 2. Recall
#
# El recall, o sensibilidad, mide la proporción de verdaderos positivos sobre el total de casos positivos reales (TP + FN). Esta métrica es esencial cuando es más importante detectar todos los casos positivos, incluso a costa de aumentar las falsas alarmas. Por ejemplo, en un sistema de detección de fraudes, perder un caso positivo (falso negativo) podría resultar costoso. Un alto recall asegura que la mayoría de los casos relevantes sean capturados.[8]
#
# 3. F1-Score
#
# El F1-score es la media armónica entre precisión y recall. Esta métrica se utiliza cuando se necesita un balance entre ambas. En situaciones donde hay un desbalance entre clases (por ejemplo, muchas más "alarmas verdaderas" que "falsas alarmas"), el F1-score proporciona una evaluación más equilibrada del rendimiento del modelo que simplemente mirar la precisión o el recall por separado. Un F1-score bajo puede indicar que el modelo no está capturando adecuadamente la clase positiva o está generando demasiadas falsas alarmas.[8]

# %% [markdown]
# # Conclusiones
#
#
# Random Forest presenta un rendimiento superior en términos de precisión, recall, F1-score y exactitud en comparación con SVM. Esto sugiere que Random Forest es más efectivo para manejar el problema específico, especialmente en la identificación de ambas clases.
# Random Forest muestra un mejor equilibrio entre la identificación de falsas y verdaderas alarmas, lo que es crucial en aplicaciones donde tanto las falsas alarmas como las verdaderas deben ser gestionadas adecuadamente.
# Dado su mejor desempeño general, Random Forest podría ser más adecuado para aplicaciones prácticas donde se requiere una alta precisión en la clasificación y una buena capacidad de generalización.
# Aunque Random Forest ha demostrado ser más efectivo en este caso, es importante considerar la posibilidad de ajustar hiperparámetros o explorar técnicas adicionales (como el uso de técnicas de balanceo de clases) para mejorar aún más el rendimiento del modelo SVM si se decide utilizarlo.
#
# Los resultados sugieren que Random Forest es una buena opción para este problema específico, proporcionando un mejor equilibrio entre precisión y recall, así como una mayor exactitud general en comparación con SVM.

# %% [markdown]
# # Citas
#
# [1] http://scielo.sld.cu/scielo.php?pid=S1684-18592018000100005&script=sci_arttext
# [2] https://www.cinc.org/archives/2015/pdf/0733.pdf
# [3] https://physionet.org/content/challenge-2015/1.0.0/
# [4] https://www.healio.com/cardiology/learn-the-heart/ecg-review/ecg-interpretation-tutorial/qrs-complex
# [5] https://www.siacardio.com/wp-content/uploads/2015/01/Libro-EKG-y-Arritmias-WU.pdf
# [6] https://www.shaio.org/bradicardia
# [7] https://www.ifi.uzh.ch/dam/jcr:88645ffa-e895-4f05-b0e0-9260cd097cda/ReportMScProjektMargolisThaqiEsati.pdf
# [8] https://klu.ai/glossary/accuracy-precision-recall-f1
